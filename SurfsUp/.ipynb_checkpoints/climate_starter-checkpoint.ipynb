# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# View all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
columns = inspector.get_columns ('measurement')

session.query(Measurement.date).order_by(Measurement.date.desc()).first()
# Out:
# ('2017-08-23',)

# %%
# Find the most recent date in the data set.

# %%
session.query(Measurement.date, Measurement.prcp).all()
# Out:
# [('2010-01-01', 0.08),
#  ('2010-01-02', 0.0),
#  ('2010-01-03', 0.0),
#  ('2010-01-04', 0.0),
#  ('2010-01-06', None),
#  ('2010-01-07', 0.06),
#  ('2010-01-08', 0.0),
#  ('2010-01-09', 0.0),
#  ('2010-01-10', 0.0),
#  ('2010-01-11', 0.01),
#  ('2010-01-12', 0.0),
#  ('2010-01-14', 0.0),
#  ('2010-01-15', 0.0),
#  ('2010-01-16', 0.0),
#  ('2010-01-17', 0.0),
#  ('2010-01-18', 0.0),
#  ('2010-01-19', 0.0),
#  ('2010-01-20', 0.0),
#  ('2010-01-21', 0.0),
#  ('2010-01-22', 0.0),
#  ('2010-01-23', 0.0),
#  ('2010-01-24', 0.01),
#  ('2010-01-25', 0.0),
#  ('2010-01-26', 0.04),
#  ('2010-01-27', 0.12),
#  ('2010-01-28', 0.0),
#  ('2010-01-30', None),
#  ('2010-01-31', 0.03),
#  ('2010-02-01', 0.01),
#  ('2010-02-03', None),
#  ('2010-02-04', 0.01),
#  ('2010-02-05', 0.0),
#  ('2010-02-06', 0.0),
#  ('2010-02-07', 0.0),
#  ('2010-02-08', 0.0),
#  ('2010-02-09', 0.0),
#  ('2010-02-11', 0.0),
#  ('2010-02-12', 0.02),
#  ('2010-02-13', 0.01),
#  ('2010-02-14', 0.0),
#  ('2010-02-15', 0.0),
# ...

# %%
One_yr_from_most_recent = '2016-08-23'

# %%
# Perform a query to retrieve the data and precipitation scores
Precip_scores = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date > One_yr_from_most_recent).all()
Precip_scores
# Out:
# [('2016-08-24', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-26', 0.0),
#  ('2016-08-27', 0.0),
#  ('2016-08-28', 0.01),
#  ('2016-08-29', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-31', 0.13),
#  ('2016-09-01', 0.0),
#  ('2016-09-02', 0.0),
#  ('2016-09-03', 0.0),
#  ('2016-09-04', 0.03),
#  ('2016-09-05', None),
#  ('2016-09-06', None),
#  ('2016-09-07', 0.05),
#  ('2016-09-08', 0.0),
#  ('2016-09-09', 0.03),
#  ('2016-09-10', 0.0),
#  ('2016-09-11', 0.05),
#  ('2016-09-12', 0.0),
#  ('2016-09-13', 0.02),
#  ('2016-09-14', 1.32),
#  ('2016-09-15', 0.42),
#  ('2016-09-16', 0.06),
#  ('2016-09-17', 0.05),
#  ('2016-09-18', 0.0),
#  ('2016-09-19', 0.0),
#  ('2016-09-20', 0.0),
#  ('2016-09-21', 0.0),
#  ('2016-09-22', 0.02),
#  ('2016-09-23', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-25', 0.0),
#  ('2016-09-26', 0.06),
#  ('2016-09-27', 0.02),
#  ('2016-09-28', 0.0),
#  ('2016-09-29', 0.0),
#  ('2016-09-30', 0.0),
#  ('2016-10-01', 0.0),
#  ('2016-10-02', 0.0),
# ...

# %%
# Save the query results as a Pandas DataFrame. Explicitly set the column names
Precip_scores_df = pd.DataFrame(Precip_scores)

Precip_scores_df
# Out:
#             date  prcp
# 0     2016-08-24  0.08
# 1     2016-08-25  0.08
# 2     2016-08-26  0.00
# 3     2016-08-27  0.00
# 4     2016-08-28  0.01
# ...          ...   ...
# 2218  2017-08-19  0.09
# 2219  2017-08-20   NaN
# 2220  2017-08-21  0.56
# 2221  2017-08-22  0.50
# 2222  2017-08-23  0.45
#
# [2223 rows x 2 columns]

# %%
Precip_scores_df = Precip_scores_df.rename(columns={"prcp":"Precipitation"})
# Sort the dataframe by date
Precip_scores_df.sort_values(by=['date'], ascending=True)
Precip_scores_df=Precip_scores_df.dropna()
Precip_scores_df.set_index('date', inplace = True)

Precip_scores_df
# Out:
#             Precipitation
# date
# 2016-08-24           0.08
# 2016-08-25           0.08
# 2016-08-26           0.00
# 2016-08-27           0.00
# 2016-08-28           0.01
# ...                   ...
# 2017-08-17           0.13
# 2017-08-19           0.09
# 2017-08-21           0.56
# 2017-08-22           0.50
# 2017-08-23           0.45
#
# [2015 rows x 1 columns]

# %%
# Sort the dataframe by date

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 

# Calculate the date one year from the last date in data set.


# Perform a query to retrieve the data and precipitation scores


# Save the query results as a Pandas DataFrame. Explicitly set the column names


# Sort the dataframe by date


# Use Pandas Plotting with Matplotlib to plot the data

# %%
import matplotlib.cbook as cbook
import matplotlib.dates as mdates

# %%
ax=Precip_scores_df.plot(color='b',figsize=(12,10),legend=True,linewidth=9.0,grid=True)
plt.setp(ax.get_xticklabels(), visible=True)
plt.tight_layout()
plt.xlabel('Date')
plt.ylabel('Inches')
plt.show()

# %%
Precip_scores_df.describe()
# Out:
#        Precipitation
# count    2015.000000
# mean        0.176462
# std         0.460288
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
# Use Pandas to calculate the summary statistics for the precipitation data

# %% [markdown]
# # Exploratory Station Analysis

# %%
#Finding columns and datatype
inspector = inspect(engine)
columns = inspector.get_columns('station')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Design a query to show how many stations are available in this dataset?
station_count=session.query(func.count(Station.id)).all()
station_count
# Out:
# [(9,)]

# %%
# Design a query to calculate the total number of stations in the dataset

# %%
Measurement_and_stations = session.query(Measurement.station, func.count(Measurement.station)) \
    .group_by(Measurement.station) \
    .order_by(func.count(Measurement.station).desc()) \
    .all()

Measurement_and_stations
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Design a query to find the most active stations (i.e. which stations have the most rows?)
# List the stations and their counts in descending order.

# %%
min_max_avg_temp=session.query(func.min(Measurement.tobs),func.max(Measurement.tobs),func.avg(Measurement.tobs))\
             .filter(Measurement.station==Measurement_and_stations[0][0]).all()
min_max_avg_temp
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.

# %%
One_yr_from_most_recent = '2016-08-23'
a_years_worth_temps=session.query(Measurement.tobs).filter((Measurement.station=='USC00519281') & 
        (Measurement.date>One_yr_from_most_recent)).all()
    
a_years_worth_temps_df = pd.DataFrame(a_years_worth_temps)

a_years_worth_temps_df
# Out:
#      tobs
# 0    77.0
# 1    80.0
# 2    80.0
# 3    75.0
# 4    73.0
# ..    ...
# 346  77.0
# 347  77.0
# 348  76.0
# 349  76.0
# 350  79.0
#
# [351 rows x 1 columns]

# %%
a_years_worth_temps_df .plot.hist(bins=12)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

# %% [markdown]
# # Close Session

# %%
Precip_scores = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date > One_yr_from_most_recent).all()
precipitation_data = []
for date, prcp in Precip_scores:
        precipitation_dict = {}
        precipitation_dict["date"] = date
        precipitation_dict["prcp"] = prcp
        precipitation_data.append(precipitation_dict)
precipitation_data
# Out:
# [{'date': '2016-08-24', 'prcp': 0.08},
#  {'date': '2016-08-25', 'prcp': 0.08},
#  {'date': '2016-08-26', 'prcp': 0.0},
#  {'date': '2016-08-27', 'prcp': 0.0},
#  {'date': '2016-08-28', 'prcp': 0.01},
#  {'date': '2016-08-29', 'prcp': 0.0},
#  {'date': '2016-08-30', 'prcp': 0.0},
#  {'date': '2016-08-31', 'prcp': 0.13},
#  {'date': '2016-09-01', 'prcp': 0.0},
#  {'date': '2016-09-02', 'prcp': 0.0},
#  {'date': '2016-09-03', 'prcp': 0.0},
#  {'date': '2016-09-04', 'prcp': 0.03},
#  {'date': '2016-09-05', 'prcp': None},
#  {'date': '2016-09-06', 'prcp': None},
#  {'date': '2016-09-07', 'prcp': 0.05},
#  {'date': '2016-09-08', 'prcp': 0.0},
#  {'date': '2016-09-09', 'prcp': 0.03},
#  {'date': '2016-09-10', 'prcp': 0.0},
#  {'date': '2016-09-11', 'prcp': 0.05},
#  {'date': '2016-09-12', 'prcp': 0.0},
#  {'date': '2016-09-13', 'prcp': 0.02},
#  {'date': '2016-09-14', 'prcp': 1.32},
#  {'date': '2016-09-15', 'prcp': 0.42},
#  {'date': '2016-09-16', 'prcp': 0.06},
# ...

# %%
# Close Session
session.close()
